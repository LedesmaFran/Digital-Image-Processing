# %% [markdown]
# # TP 2 - Procesamiento de Imagenes - ex2.m
# Grupo 4 <br>
# Integrantes:
# - Pablo Smolkin
# - Pedro Carranza Vélez
# - Philippe Dutriez Diaz
# - Francisco Daniel Ledesma
#
# Nota: Las funciones utilizadas se encuentran en el archivo functions.py

# %%
import sys
sys.path.append("D:/ITBA-2022-Q2/Imag/Imagenes-GIT/Digital-Image-Processing/")
from common.functions import *

# %%
from functions import *

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ***

# %% [markdown]
# ## Load and display Barbara image

# %%
b = cv2.imread('img/barbara.jpg')
h, w, channels = b.shape
plotImage(b,w,h)

# %% [markdown]
# ## imagen de barbara filtrada por h0
#
# \begin{equation}
#     h_0 =
#     \begin{bmatrix}
#     0 & 1/6 & 0 \\
#     1/6 & 1/3 & 1/6 \\
#     0 & 1/6 & 0
#     \end{bmatrix}
# \end{equation}

# %%
h0 = np.array([[0,1/6,0],[1/6,1/3,1/6],[0,1/6,0]])
img_f = cv2.filter2D(b,-1,h0)
plotImage(img_f,w,h)

# %% [markdown]
# ## Imagen de barbara filtrada por un pasabajos

# %%
h1 = disk(5) #Low pass
img_f = cv2.filter2D(b,-1,h1)
plotImage(img_f,w,h)

# %% [markdown]
# ## Imagen de Barbara filtrada por un pasa altos

# %%
h2 = unsharp(0.2) #High pass
img_f = cv2.filter2D(b,-1,h2)
plotImage(img_f,w,h)
