# %% [markdown]
# # TP 2 - Procesamiento de Imagenes - ex2.m
# Grupo 4 <br>
# Integrantes:
# - Pablo Smolkin
# - Pedro Carranza Vélez
# - Philippe Dutriez Diaz
# - Francisco Daniel Ledesma

# %%
import sys
sys.path.append("D:/ITBA-2022-Q2/Imag/Imagenes-GIT/Digital-Image-Processing/")
from common.functions import *

# %%
from functions import *

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import cv2 #python -m pip install opencv-python  #ultimo recurso
b = cv2.imread('img/barbara.jpg')
cv2.imshow('Unfiltered', b)
cv2.waitKey(0)
h0 = np.array([[0,1/6,0],[1/6,1/3,1/6],[0,1/6,0]])
h0 = skimage.morphology.disk(radius=1)
h0 = unsharp(0.2) #High pass
img_filtered = cv2.filter2D(b,-1,h0)
cv2.imshow('filtered', img_filtered)
cv2.waitKey(0)
# Out:
# -1

# %%
b = Image.open('img/barbara.jpg')
w,h = b.size
displayImage(b, w, h)
# Out:
# <PIL.Image.Image image mode=L size=720x580>

# %%
h0 = np.array([[0,1/6,0],[1/6,1/3,1/6],[0,1/6,0]])
img_f = scipy.ndimage.correlate(b, h0, mode='nearest')
fig = px.imshow(img_f,binary_string=True)
fig.update_layout(width=w, height=h, margin=dict(l=0, r=0, b=0, t=0))
fig.show()

# %%
h1 = skimage.morphology.disk(radius=0.9999)    #Low pass
img_f = scipy.ndimage.correlate(b, h1, mode='nearest')
fig = px.imshow(img_f,binary_string=True)
fig.update_layout(width=w, height=h, margin=dict(l=0, r=0, b=0, t=0))
fig.show()

# %%
h2 = unsharp(0.2) #High pass
img_f = scipy.ndimage.correlate(b, h2, mode='nearest')
fig = px.imshow(img_f,binary_string=True)
fig.update_layout(width=w, height=h, margin=dict(l=0, r=0, b=0, t=0))
fig.show()
